# %% [markdown]
# ## Research problem

# %% [markdown]
# Write a simple code to obtain a force dicplacment curve for different stiffness values.

# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# Define a function to plot the data
def plot_data(freq):
    x = np.linspace(0, 10, 1000)
    y = np.sin(freq * x)
    plt.plot(x, y)
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.title('Sine Wave')
    plt.show()

# Create a slider widget
freq_slider = widgets.FloatSlider(
    value=1.0,
    min=0.5,
    max=2.0,
    step=0.1,
    description='Frequency:'
)

# Define a function to update the plot when the slider is moved
def update_plot(change):
    freq = change.new
    plot_data(freq)

# Connect the slider to the update_plot function
freq_slider.observe(update_plot, 'value')

# Display the slider widget
display(freq_slider)

# Plot the initial data
plot_data(freq_slider.value)
# Out:
# FloatSlider(value=1.0, description='Frequency:', max=2.0, min=0.5)

# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

# Define a function to plot the data
def plot_data(freq):
    x = np.linspace(0, 10, 1000)
    y = np.sin(freq * x)
    z = np.cos(freq * x)
    plt.plot(x, y)
    plt.plot(x,z)

    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.title('Sine-Cos Wave')
    plt.show()

# Use the @interact decorator to create a slider widget
@interact(freq=(0.5, 2.0, 0.1))
def update_plot(freq=1.0):
    plot_data(freq)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='freq', max=2.0, min=0.5), Output()), _dom_classes=('…

# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# Define initial point coordinates and plot them
x1, y1 = 1, 3
x2, y2 = 2, 5

fig, ax = plt.subplots()
ax.scatter(x1, y1, color='blue', s=100)
ax.scatter(x2, y2, color='red', s=100)
ax.plot([x1, x2], [y1, y2], color='gray', linestyle='--')
ax.set_xlim(0, 3)
ax.set_ylim(-10, 10)
ax.set_aspect('auto')
#plt.show()

# Define two slider widgets for the point positions
x1_slider = widgets.FloatSlider(
    value=x1,
    min=0,
    max=10,
    step=0.1,
    description='X1:'
)
y1_slider = widgets.FloatSlider(
    value=y1,
    min=-10,
    max=10,
    step=0.1,
    description='Y1:'
)
x2_slider = widgets.FloatSlider(
    value=x2,
    min=0,
    max=10,
    step=0.1,
    description='X2:'
)
y2_slider = widgets.FloatSlider(
    value=y2,
    min=-10,
    max=10,
    step=0.1,
    description='Y2:'
)

# Define a function to update the plot when the sliders are moved
def update_plot(x1, y1, x2, y2):
    fig, ax = plt.subplots()
    ax.scatter(x1, y1, color='blue', s=100)
    ax.scatter(x2, y2, color='red', s=100)
    ax.plot([x1, x2], [y1, y2], color='gray', linestyle='--')
    ax.set_xlim(0, 3)
    ax.set_ylim(0, 10)
    ax.set_aspect('auto')
    plt.show()

# Connect the sliders to the update_plot function
widgets.interact(
    update_plot,
    x1=x1_slider,
    y1=y1_slider,
    x2=x2_slider,
    y2=y2_slider
)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='X1:', max=10.0), FloatSlider(value=3.0, description=…
# <function __main__.update_plot(x1, y1, x2, y2)>
